# %% [markdown]
# ##  1.Insertion at begining

# %% [markdown]
# time complexity is O(1)

# %% [markdown]
# ptr is a pointer it only store the address.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##  2. insertion in between

# %% [markdown]
# worst case compelxity is O(n)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3. insertion at end

# %% [markdown]
# worst case compelxity is O(n)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 4. insertion at any given node

# %% [markdown]
# time complexity is O(1)

# %% [markdown]
# ![image.png](attachment:image.png)
