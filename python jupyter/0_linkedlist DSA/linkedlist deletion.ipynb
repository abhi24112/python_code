# %% [markdown]
# ## 1. delete first element

# %% [markdown]
# time complexity is the O(1)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2.deleting  element in between

# %% [markdown]
# time complexity is the O()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3. deleting last element

# %% [markdown]
# ![image.png](attachment:image.png)
